# %% [markdown]
# # Getting Started with Azure Machine Learning
#
# Azure Machine Learning (*Azure ML*) is a cloud-based service for creating and managing machine learning solutions. It's designed to help data scientists leverage their existing data processing and model development skills and frameworks, and help them scale their workloads to the cloud. The Azure ML SDK for Python provides classes you can use to work with Azure ML in your Azure subscription.
#
# ## Before You Start
#
# 1. Complete the steps in [Lab 1 - Getting Started with Azure Machine Learning](./labdocs/Lab01.md) to create an Azure Machine Learning workspace and a compute instance with the contents of this repo.
# 2. Open this notebook in the compute instance and run it there.
#
# ## Check the Azure ML SDK Version
#
# Let's start by importing the **azureml-core** package and checking the version of the SDK that is installed. Click the cell below and then use the **&#9658; Run** button on the toolbar to run it.

# %%
# !pip install azure-ai-ml
# Out:
# Requirement already satisfied: azure-ai-ml in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (1.30.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (6.0.2)
# Requirement already satisfied: azure-core>=1.23.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.37.0)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.25.1)
# Requirement already satisfied: tqdm<5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.67.1)
# Requirement already satisfied: strictyaml<2.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (0.4.6)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (2.10.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.19.0)
# Requirement already satisfied: azure-storage-file-share in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.23.1)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.22.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (8.0.5)
# Requirement already satisfied: isodate<1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.1.28)
# Requirement already satisfied: typing-extensions<5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.14.1)
# Requirement already satisfied: azure-monitor-opentelemetry in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.27.0)
# Requirement already satisfied: packaging>=17.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml) (25.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from strictyaml<2.0.0->azure-ai-ml) (2.9.0.post0)
# Requirement already satisfied: requests>=2.21.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core>=1.23.0->azure-ai-ml) (2.32.5)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob>=12.10.0->azure-ai-ml) (45.0.7)
# Collecting azure-storage-blob>=12.10.0 (from azure-ai-ml)
#   Using cached azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.10.0->azure-ai-ml) (2.0.0)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob>=12.10.0->azure-ai-ml) (2.22)
# Requirement already satisfied: six>=1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from python-dateutil>=2.6.0->strictyaml<2.0.0->azure-ai-ml) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (2025.8.3)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.0.0b12)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter~=1.0.0b46 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.0.0b46)
# Requirement already satisfied: opentelemetry-sdk==1.39 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.39.0)
# Requirement already satisfied: opentelemetry-instrumentation-django==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure<1.0.0,>=0.1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.1.5)
# Requirement already satisfied: opentelemetry-api~=1.12 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (1.39.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-util-http==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.60b0->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.60b0->opentelemetry-instrumentation-fastapi==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (3.11.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-psycopg2==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (8.7.0)
# Requirement already satisfied: azure-identity~=1.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (1.25.1)
# Requirement already satisfied: msrest>=0.6.10 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (7.0.0)
# Requirement already satisfied: msal>=1.30.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity~=1.17->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (1.3.1)
# Requirement already satisfied: zipp>=3.20 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (3.23.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (3.3.1)
# Using cached azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.19.0
#     Uninstalling azure-storage-blob-12.19.0:
#       Successfully uninstalled azure-storage-blob-12.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azureml-mlflow 1.60.0 requires azure-storage-blob<=12.19.0,>=12.5.0, but you have azure-storage-blob 12.27.1 which is incompatible.
# Successfully installed azure-storage-blob-12.27.1

# %%
# !brew update
# Out:
# ==> Updating Homebrew...
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# git-get: Better way to clone, organize and manage multiple git repositories
# ==> Outdated Formulae
# xz
#
# You have 1 outdated formula installed.
# You can upgrade it with brew upgrade
# or list it with brew outdated.

# %%
# !brew upgrade
# Out:
# ==> Upgrading 1 outdated package:
# xz 5.8.1 -> 5.8.2
# ==> Fetching downloads for: xz
# ⠋ Bottle xz (5.8.2)⠋ Bottle xz (5.8.2)⠙ Bottle xz (5.8.2)⠙ Bottle xz (5.8.2)⠚ Bottle xz (5.8.2)⠚ Bottle xz (5.8.2)⠞ Bottle xz (5.8.2)⠞ Bottle xz (5.8.2)                                [Downloading  98.3KB/764.9KB]⠖ Bottle xz (5.8.2)                                [Downloading 241.7KB/764.9KB]⠖ Bottle xz (5.8.2)                                [Downloading 471.0KB/764.9KB]⠦ Bottle xz (5.8.2)                                [Downloading 602.1KB/764.9KB]⠦ Bottle xz (5.8.2)                                [Downloading 667.6KB/764.9KB]⠴ Bottle xz (5.8.2)                                [Extracting  764.9KB/764.9KB]✔︎ Bottle xz (5.8.2)                                [Downloaded  764.9KB/764.9KB]
# ==> Upgrading xz
#   5.8.1 -> 5.8.2
# ==> Pouring xz--5.8.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xz/5.8.2: 96 files, 2.7MB
# ==> Running `brew cleanup xz`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# Removing: /opt/homebrew/Cellar/xz/5.8.1... (96 files, 2.6MB)
# Removing: /Users/augustvollbrecht/Library/Caches/Homebrew/xz_bottle_manifest--5.8.1... (14.5KB)
# Removing: /Users/augustvollbrecht/Library/Caches/Homebrew/xz--5.8.1... (748.1KB)

# %%
# !brew install azure-cli
# Out:
# Warning: azure-cli 2.81.0 is already installed and up-to-date.
# To reinstall 2.81.0, run:
#   brew reinstall azure-cli

# %%
# !az version
# Out:
# {
#   "azure-cli": "2.81.0",
#   "azure-cli-core": "2.81.0",
#   "azure-cli-telemetry": "1.1.0",
#   "extensions": {}
# }

# %%
# !pip install azure-ai-ml azure-identity
# Out:
# Requirement already satisfied: azure-ai-ml in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (1.30.0)
# Requirement already satisfied: azure-identity in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (1.25.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (6.0.2)
# Requirement already satisfied: azure-core>=1.23.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.37.0)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.25.1)
# Requirement already satisfied: tqdm<5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.67.1)
# Requirement already satisfied: strictyaml<2.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (0.4.6)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (2.10.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.27.1)
# Requirement already satisfied: azure-storage-file-share in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.23.1)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (12.22.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (8.0.5)
# Requirement already satisfied: isodate<1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.1.28)
# Requirement already satisfied: typing-extensions<5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (4.14.1)
# Requirement already satisfied: azure-monitor-opentelemetry in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-ai-ml) (1.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml) (0.27.0)
# Requirement already satisfied: packaging>=17.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml) (25.0)
# Requirement already satisfied: python-dateutil>=2.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from strictyaml<2.0.0->azure-ai-ml) (2.9.0.post0)
# Requirement already satisfied: cryptography>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity) (45.0.7)
# Requirement already satisfied: msal>=1.30.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core>=1.23.0->azure-ai-ml) (2.32.5)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-ai-ml) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from python-dateutil>=2.6.0->strictyaml<2.0.0->azure-ai-ml) (1.17.0)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.0.0b12)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter~=1.0.0b46 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.0.0b46)
# Requirement already satisfied: opentelemetry-sdk==1.39 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.39.0)
# Requirement already satisfied: opentelemetry-instrumentation-django==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure<1.0.0,>=0.1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.1.5)
# Requirement already satisfied: opentelemetry-api~=1.12 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (1.39.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: opentelemetry-util-http==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.60b0->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-fastapi==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-asgi==0.60b0->opentelemetry-instrumentation-fastapi==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (3.11.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-instrumentation-psycopg2==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (0.60b0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (8.7.0)
# Requirement already satisfied: msrest>=0.6.10 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (7.0.0)
# Requirement already satisfied: zipp>=3.20 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.12->opentelemetry-instrumentation-django==0.60b0->azure-monitor-opentelemetry->azure-ai-ml) (3.23.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter~=1.0.0b46->azure-monitor-opentelemetry->azure-ai-ml) (3.3.1)

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

# Example usage (adjust for your specific code)
# ml_client = MLClient.from_config(credential=DefaultAzureCredential())

# %%
print("Ready to use Azure ML", azure.ai.ml.VERSION)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print("Ready to use Azure ML", azure.ai.ml.VERSION)
#
# NameError: name 'azure' is not defined

# %% [markdown]
# ## Connect to Your Workspace
#
# All experiments and associated resources are managed within you Azure ML workspace. You can connect to an existing workspace, or create a new one using the Azure ML SDK.
#
# In most cases, you should store the workspace configuration in a JSON configuration file. This makes it easier to reconnect without needing to remember details like your Azure subscription ID. You can download the JSON configuration file from the blade for your workspace in the Azure portal, but if you're using a Compute Instance within your workspace, the configuration file has alreday been downloaded to the root folder.
#
# The code below uses the configuration file to connect to your workspace. The first time you run it in a notebook session, you'll be prompted to sign into Azure by clicking the https://microsoft.com/devicelogin link,  entering an automatically generated code, and signing into Azure. After you have successfully signed in, you can close the browser tab that was opened, return to this notebook, and wait for the sign-in process to complete.

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

try:
    # Load the workspace configuration from local cached info
    # The DefaultAzureCredential will try to find credentials in the environment
    ml_client = MLClient.from_config(credential=DefaultAzureCredential())
    print(ml_client.workspace_name, "loaded")
except Exception as e:
    print("Workspace not found or connection failed:", e)
# Out:
# Found the config file in: ./config.json
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# azure-ml-workspace loaded

# %% [markdown]
# ## Run an Experiment
#
# One of the most fundamentals tasks that data scientists need to perform is to create and run experiments that process and analyze data. In this exercise, you'll learn how to use an Azure ML *experiment* to run Python code and record values extracted from data. In this case, you'll use a simple dataset that contains details of patients that have been tested for diabetes. You'll run an experiment to explore the data, extracting statistics, visualizations, and data samples. Most of the code you'll use is fairly generic Python, such as you might run in any data exploration process. However, with the addition of a few lines, the code uses an Azure ML *experiment* to log details of the run.

# %%
# !pip install azureml-mlflow
# Out:
# Requirement already satisfied: azureml-mlflow in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (1.61.0.post1)
# Requirement already satisfied: jsonpickle<5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (4.1.1)
# Requirement already satisfied: mlflow-skinny<=3.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (3.5.0)
# Requirement already satisfied: azure-identity in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.25.1)
# Requirement already satisfied: msrest>=0.6.18 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (0.7.1)
# Requirement already satisfied: azure-core!=1.22.0,<2.0.0,>=1.8.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.37.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.6.0)
# Collecting azure-storage-blob<=12.19.0,>=12.5.0 (from azureml-mlflow)
#   Using cached azure_storage_blob-12.19.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: azure-common<2.0.0,>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.1.28)
# Requirement already satisfied: cryptography<46.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (45.0.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (2.9.0.post0)
# Requirement already satisfied: pytz<=2025.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (2025.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (4.14.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob<=12.19.0,>=12.5.0->azureml-mlflow) (0.7.2)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography<46.0.0->azureml-mlflow) (2.0.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (0.76.0)
# Requirement already satisfied: fastapi<1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (0.125.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (1.39.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (1.39.0)
# Requirement already satisfied: packaging<26 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (6.33.2)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (2.11.7)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (6.0.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (0.5.4)
# Requirement already satisfied: uvicorn<1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny<=3.5.0->azureml-mlflow) (0.38.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny<=3.5.0->azureml-mlflow) (2.45.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny<=3.5.0->azureml-mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny<=3.5.0->azureml-mlflow) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny<=3.5.0->azureml-mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny<=3.5.0->azureml-mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<=3.5.0->azureml-mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<=3.5.0->azureml-mlflow) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny<=3.5.0->azureml-mlflow) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<=3.5.0->azureml-mlflow) (0.60b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<=3.5.0->azureml-mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<=3.5.0->azureml-mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny<=3.5.0->azureml-mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.7.3->azureml-mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core!=1.22.0,<2.0.0,>=1.8.0->azureml-mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny<=3.5.0->azureml-mlflow) (0.6.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<=3.5.0->azureml-mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<=3.5.0->azureml-mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny<=3.5.0->azureml-mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography<46.0.0->azureml-mlflow) (2.22)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from msrest>=0.6.18->azureml-mlflow) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azureml-mlflow) (3.3.1)
# Requirement already satisfied: msal>=1.30.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity->azureml-mlflow) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity->azureml-mlflow) (1.3.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->azureml-mlflow) (2.10.1)
# Using cached azure_storage_blob-12.19.0-py3-none-any.whl (394 kB)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.27.1
#     Uninstalling azure-storage-blob-12.27.1:
#       Successfully uninstalled azure-storage-blob-12.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azure-storage-file-datalake 12.22.0 requires azure-storage-blob>=12.27.0, but you have azure-storage-blob 12.19.0 which is incompatible.
# Successfully installed azure-storage-blob-12.19.0

# %%
# !pip install --upgrade azure-storage-blob
# Out:
# Requirement already satisfied: azure-storage-blob in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (12.19.0)
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob) (1.37.0)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob) (45.0.7)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob) (4.14.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.5)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography>=2.1.4->azure-storage-blob) (2.0.0)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.8.3)
# Using cached azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.19.0
#     Uninstalling azure-storage-blob-12.19.0:
#       Successfully uninstalled azure-storage-blob-12.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azureml-mlflow 1.61.0.post1 requires azure-storage-blob<=12.19.0,>=12.5.0, but you have azure-storage-blob 12.27.1 which is incompatible.
# Successfully installed azure-storage-blob-12.27.1

# %%
# !pip show azure-storage-blob
# Out:
# Name: azure-storage-blob
# Version: 12.27.1
# Summary: Microsoft Azure Blob Storage Client Library for Python
# Home-page: https://github.com/Azure/azure-sdk-for-python/tree/main/sdk/storage/azure-storage-blob
# Author: Microsoft Corporation
# Author-email: ascl@microsoft.com
# License: MIT License
# Location: /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages
# Requires: azure-core, cryptography, isodate, typing-extensions
# Required-by: azure-ai-ml, azure-storage-file-datalake, azureml-mlflow

# %%
# !pip install azure-storage-blob==12.19.0
# Out:
# Requirement already satisfied: azure-storage-blob==12.19.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (12.19.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob==12.19.0) (1.37.0)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob==12.19.0) (45.0.7)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob==12.19.0) (4.14.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob==12.19.0) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.0) (2.32.5)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography>=2.1.4->azure-storage-blob==12.19.0) (2.0.0)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography>=2.1.4->azure-storage-blob==12.19.0) (2.22)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob==12.19.0) (2025.8.3)

# %%
# !pip install mlflow azureml-mlflow
# Out:
# Requirement already satisfied: mlflow in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (3.7.0)
# Requirement already satisfied: azureml-mlflow in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (1.60.0)
# Requirement already satisfied: mlflow-skinny==3.7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (3.7.0)
# Requirement already satisfied: mlflow-tracing==3.7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (3.7.0)
# Requirement already satisfied: Flask-CORS<7 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (2.5.5)
# Requirement already satisfied: matplotlib<4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (3.10.5)
# Requirement already satisfied: numpy<3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (2.2.6)
# Requirement already satisfied: pandas<3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (2.3.1)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (1.7.1)
# Requirement already satisfied: scipy<2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (1.16.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow) (2.0.45)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (0.76.0)
# Requirement already satisfied: fastapi<1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (0.125.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (1.39.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (1.39.0)
# Requirement already satisfied: packaging<26 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (6.33.2)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (2.11.7)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (0.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (4.14.1)
# Requirement already satisfied: uvicorn<1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from mlflow-skinny==3.7.0->mlflow) (0.38.0)
# Requirement already satisfied: Mako in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: cffi>=1.14 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (2.45.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.7.0->mlflow) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.7.0->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from Flask<4->mlflow) (3.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.7.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.7.0->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.7.0->mlflow) (0.60b0)
# Requirement already satisfied: pytz>=2020.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.7.0->mlflow) (0.4.1)
# Requirement already satisfied: six>=1.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.7.0->mlflow) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.7.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.7.0->mlflow) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.7.0->mlflow) (0.16.0)
# Requirement already satisfied: jsonpickle in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (4.1.1)
# Requirement already satisfied: azure-identity in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.25.1)
# Requirement already satisfied: msrest>=0.6.18 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (0.7.1)
# Requirement already satisfied: azure-core!=1.22.0,<2.0.0,>=1.8.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.37.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.6.0)
# Collecting azure-storage-blob<=12.19.0,>=12.5.0 (from azureml-mlflow)
#   Using cached azure_storage_blob-12.19.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: azure-common<2.0.0,>=1.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azureml-mlflow) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-storage-blob<=12.19.0,>=12.5.0->azureml-mlflow) (0.7.2)
# Requirement already satisfied: pycparser in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from cffi>=1.14->cryptography<47,>=43.0.0->mlflow) (2.22)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from msrest>=0.6.18->azureml-mlflow) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azureml-mlflow) (3.3.1)
# Requirement already satisfied: msal>=1.30.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity->azureml-mlflow) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from azure-identity->azureml-mlflow) (1.3.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/augustvollbrecht/virtual/new_dsb/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->azureml-mlflow) (2.10.1)
# Using cached azure_storage_blob-12.19.0-py3-none-any.whl (394 kB)
# Installing collected packages: azure-storage-blob
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 12.27.1
#     Uninstalling azure-storage-blob-12.27.1:
#       Successfully uninstalled azure-storage-blob-12.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# azure-storage-file-datalake 12.22.0 requires azure-storage-blob>=12.27.0, but you have azure-storage-blob 12.19.0 which is incompatible.
# Successfully installed azure-storage-blob-12.19.0

# %%
# V2: Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import mlflow
import mlflow.azureml
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

# V2: Connect to your workspace (ensure config.json is present or provide details)
# Substitute with your own values for subscription_id, resource_group, and workspace_name
subscription_id = "YOUR_SUBSCRIPTION_ID"
resource_group = "YOUR_RESOURCE_GROUP"
workspace_name = "YOUR_WORKSPACE_NAME"

ml_client = MLClient(
    DefaultAzureCredential(), subscription_id, resource_group, workspace_name
)

# V2: Set the MLflow tracking URI to the Azure ML workspace
mlflow.set_tracking_uri(ml_client.workspaces.get(workspace_name).mlflow_tracking_uri)

# OLD 
# from azureml.core import Experiment
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline 

# # Create an Azure ML experiment in your workspace
# experiment = Experiment(workspace = ws, name = "diabetes-experiment")

# # Start logging data from the experiment
# run = experiment.start_logging()
# print("Starting experiment:", experiment.name)

# # load the data from a local file
# data = pd.read_csv('data/diabetes.csv')

# # Count the rows and log the result
# row_count = (len(data))
# run.log('observations', row_count)
# print('Analyzing {} rows of data'.format(row_count))

# # Plot and log the count of diabetic vs non-diabetic patients
# diabetic_counts = data['Diabetic'].value_counts()
# fig = plt.figure(figsize=(6,6))
# ax = fig.gca()    
# diabetic_counts.plot.bar(ax = ax) 
# ax.set_title('Patients with Diabetes') 
# ax.set_xlabel('Diagnosis') 
# ax.set_ylabel('Patients')
# plt.show()
# run.log_image(name = 'label distribution', plot = fig)

# # log distinct pregnancy counts
# pregnancies = data.Pregnancies.unique()
# run.log_list('pregnancy categories', pregnancies)

# # Log summary statistics for numeric columns
# med_columns = ['PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness', 'SerumInsulin', 'BMI']
# summary_stats = data[med_columns].describe().to_dict()
# for col in summary_stats:
#     keys = list(summary_stats[col].keys())
#     values = list(summary_stats[col].values())
#     for index in range(len(keys)):
#         run.log_row(col, stat = keys[index], value = values[index])
        
# # Save a sample of the data and upload it to the experiment output
# data.sample(100).to_csv('sample.csv', index=False, header=True)
# run.upload_file(name = 'outputs/sample.csv', path_or_stream = './sample.csv')

# # Complete the run
# run.complete()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 5
#       3 import matplotlib.pyplot as plt
#       4 import mlflow
# ----> 5 import mlflow.azureml
#       6 from azure.ai.ml import MLClient
#       7 from azure.identity import DefaultAzureCredential
#
# ModuleNotFoundError: No module named 'mlflow.azureml'

# %% [markdown]
# ## View Experiment Results
#
# After the experiment has been finished, you can use the **run** object to get information about the run and its outputs:

# %%
# !git add .
# !git commit -m "Added Azure ML setup and experiment logging code"
# !git push
# Out:
# [git-push b0c8e06] Added Azure ML setup and experiment logging code
#  3 files changed, 489 insertions(+), 162 deletions(-)
# fatal: The current branch git-push has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin git-push
#
# To have this happen automatically for branches without a tracking
# upstream, see 'push.autoSetupRemote' in 'git help config'.

# %%
import json

# Get run details
details = run.get_details()
print(details)

# Get logged metrics
metrics = run.get_metrics()
print(json.dumps(metrics, indent=2))

# Get output files
files = run.get_file_names()
print(json.dumps(files, indent=2))

# %% [markdown]
# In Jupyter Notebooks, you can use the **RunDetails** widget to get a better visualization of the run details, while the experiment is running or after it has finished.

# %%
from azureml.widgets import RunDetails

RunDetails(run).show()

# %% [markdown]
# Note that the **RunDetails** widget includes a link to view the run in Azure Machine Learning studio. Click this to open a new browser tab with the run details (you can also just open [Azure Machine Learning studio](https://ml.azure.com) and find the run on the **Experiments** page). When viewing the run in Azure Machine Learning studio, note the following:
#
# - The **Details** tab contains the general properties of the experiment run.
# - The **Metrics** tab enables you to select logged metrics and view them as tables or charts.
# - The **Images** tab enables you to select and view any images or plots that were logged in the experiment (in this case, the *Label Distribution* plot)
# - The **Child Runs** tab lists any child runs (in this experiment there are none).
# - The **Outputs + Logs** tab shows the output or log files generated by the experiment.
# - The **Snapshot** tab contains all files in the folder where the experiment code was run (in this case, everything in the same folder as this notebook).
# - The **Explanations** tab is used to show model explanations generated by the experiment (in this case, there are none).
# - The **Fairness** tab is used to visualize predictive performance disparities that help you evaluate the fairness of machine learning models (in this case, there are none).
#
# ## Run an Experiment Script
#
# In the previous example, you ran an experiment inline in this notebook. A more flexible solution is to create a separate script for the experiment, and store it in a folder along with any other files it needs, and then use Azure ML to run the experiment based on the script in the folder.
#
# First, let's create a folder for the experiment files, and copy the data into it:

# %%
import os, shutil

# Create a folder for the experiment files
folder_name = 'diabetes-experiment-files'
experiment_folder = './' + folder_name
os.makedirs(folder_name, exist_ok=True)

# Copy the data file into the experiment folder
shutil.copy('data/diabetes.csv', os.path.join(folder_name, "diabetes.csv"))

# %% [markdown]
# Now we'll create a Python script containing the code for our experiment, and save it in the experiment folder.
#
# > **Note**: running the following cell just *creates* the script file - it doesn't run it!

# %%
# %%writefile $folder_name/diabetes_experiment.py
from azureml.core import Run
import pandas as pd
import os

# Get the experiment run context
run = Run.get_context()

# load the diabetes dataset
data = pd.read_csv('diabetes.csv')

# Count the rows and log the result
row_count = (len(data))
run.log('observations', row_count)
print('Analyzing {} rows of data'.format(row_count))

# Count and log the label counts
diabetic_counts = data['Diabetic'].value_counts()
print(diabetic_counts)
for k, v in diabetic_counts.items():
    run.log('Label:' + str(k), v)
      
# Save a sample of the data in the outputs folder (which gets uploaded automatically)
os.makedirs('outputs', exist_ok=True)
data.sample(100).to_csv("outputs/sample.csv", index=False, header=True)

# Complete the run
run.complete()

# %% [markdown]
# This code is a simplified version of the inline code used before. However, note the following:
# - It uses the `Run.get_context()` method to retrieve the experiment run context when the script is run.
# - It loads the diabetes data from the folder where the script is located.
# - It creates a folder named **outputs** and writes the sample file to it - this folder is automatically uploaded to the experiment run
#
# Now you're almost ready to run the experiment. To run the script, you must create a **ScriptRunConfig** that identifies the Python script file to be run in the experiment, and then run an experiment based on it.
#
# > **Note**: The ScriptRunConfig also determines the compute target and Python environment. If you don't specify these, a default environment is created automatically on the local compute where the code is being run (in this case, where this notebook is being run).
#
# The following cell configures and submits the script-based experiment.
#
# > **Note**: This will take a little longer to run the first time, as the environment must be created.

# %%
import os
import sys
from azureml.core import Experiment, ScriptRunConfig
from azureml.widgets import RunDetails


# Create a script config
script_config = ScriptRunConfig(source_directory=experiment_folder, 
                      script='diabetes_experiment.py') 

# submit the experiment
experiment = Experiment(workspace = ws, name = 'diabetes-experiment')
run = experiment.submit(config=script_config)
RunDetails(run).show()
run.wait_for_completion()

# %% [markdown]
# As before, you can use the widget or the link to the experiment in [Azure Machine Learning studio](https://ml.azure.com) to view the outputs generated by the experiment, and you can also write code to retrieve the metrics and files it generated:

# %%
# Get logged metrics
metrics = run.get_metrics()
for key in metrics.keys():
        print(key, metrics.get(key))
print('\n')
for file in run.get_file_names():
    print(file)

# %% [markdown]
# ## View Experiment Run History
#
# Now that you've run experiments multiple times, you can view the history in [Azure Machine Learning studio](https://ml.azure.com) and explore each logged run. Or you can retrieve an experiment by name from the workspace and iterate through its runs using the SDK:

# %%
from azureml.core import Experiment, Run

diabetes_experiment = ws.experiments['diabetes-experiment']
for logged_run in diabetes_experiment.get_runs():
    print('Run ID:', logged_run.id)
    metrics = logged_run.get_metrics()
    for key in metrics.keys():
        print('-', key, metrics.get(key))

# %% [markdown]
# ## Use MLflow
#
# MLflow is an open source platform for managing machine learning processes. It's commonly (but not exclusively) used in Databricks environments to coordinate experiments and track metrics. In Azure Machine Learning experiments, you can use MLflow to track metrics instead of the native log functionality if you desire.
#
# To take advantage of this capability, you'll need the **mlflow** and **azureml-mlflow** packages.

# %%
# !pip install --upgrade mlflow azureml-mlflow

# %% [markdown]
# ### Use MLflow with an Inline Experiment
#
# To use MLflow to track metrics for an inline experiment, you must set the MLflow *tracking URI* to the workspace where the experiment is being run. This enables you to use **mlflow** tracking methods to log data to the experiment run.

# %%
from azureml.core import Experiment
import pandas as pd
import mlflow

# Set the MLflow tracking URI to the workspace
mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri())

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='diabetes-mlflow-experiment')
mlflow.set_experiment(experiment.name)

# start the MLflow experiment
with mlflow.start_run():
    
    print("Starting experiment:", experiment.name)
    
    # Load data
    data = pd.read_csv('data/diabetes.csv')

    # Count the rows and log the result
    row_count = (len(data))
    print('observations:', row_count)
    mlflow.log_metric('observations', row_count)
    
# Get a link to the experiment in Azure ML studio        
experiment_url = experiment.get_portal_url()
print('See details at', experiment_url)

# %% [markdown]
# After running the code above, you can use the link that is displayed to view the experiment in Azure Machine Learning studio. Then select the latest run of tghe experiment and view it **Metrics** tab to see the logged metric.
#
# ### Use MLflow in an Experiment Script
#
# You can also use MLflow to track metrics in an experiment script.
#
# Run the following two cells to create a folder and a script for an experiment that uses MLflow.

# %%
import os, shutil

# Create a folder for the experiment files
folder_name = 'mlflow-experiment-files'
experiment_folder = './' + folder_name
os.makedirs(folder_name, exist_ok=True)

# Copy the data file into the experiment folder
shutil.copy('data/diabetes.csv', os.path.join(folder_name, "diabetes.csv"))

# %%
# %%writefile $folder_name/mlflow_diabetes.py
from azureml.core import Run
import pandas as pd
import mlflow

# start the MLflow experiment
with mlflow.start_run():
       
    # Load data
    data = pd.read_csv('diabetes.csv')

    # Count the rows and log the result
    row_count = (len(data))
    print('observations:', row_count)
    mlflow.log_metric('observations', row_count)

# %% [markdown]
# When you use MLflow tracking in an Azure ML experiment script, the MLflow tracking URI is set automatically when you start the experiment run. However, the environment in which the script is to be run must include the required **mlflow** packages.

# %%
from azureml.core import Experiment, ScriptRunConfig, Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.widgets import RunDetails


# Create a Python environment for the experiment
mlflow_env = Environment("mlflow-env")

# Ensure the required packages are installed
packages = CondaDependencies.create(conda_packages=['pandas','pip'],
                                    pip_packages=['mlflow','azureml-mlflow'])
mlflow_env.python.conda_dependencies = packages

# Create a script config
script_mlflow = ScriptRunConfig(source_directory=experiment_folder,
                                script='mlflow_diabetes.py',
                                environment=mlflow_env) 

# submit the experiment
experiment = Experiment(workspace=ws, name='diabetes-mlflow-script')
run = experiment.submit(config=script_mlflow)
RunDetails(run).show()
run.wait_for_completion()

# %% [markdown]
# As usual, you can get the logged metrics from the experiment run when it's finished.

# %%
# Get logged metrics
metrics = run.get_metrics()
for key in metrics.keys():
        print(key, metrics.get(key))

# %% [markdown]
# Now you've seen how to use the Azure ML SDK to view the resources in your workspace and run experiments.
#
# ### Learn More
#
# - For more details about the SDK, see the [Azure ML SDK documentation](https://docs.microsoft.com/python/api/overview/azure/ml/intro?view=azure-ml-py).
# - To find out more about running experiments, see [Start, monitor, and cancel training runs in Python](https://docs.microsoft.com/azure/machine-learning/how-to-manage-runs) in the Azure ML documentation.
# - For details of how to log metrics in a run, see [Monitor Azure ML experiment runs and metrics](https://docs.microsoft.com/azure/machine-learning/how-to-track-experiments).
# - For more information about integrating Azure ML experiments with MLflow, see [Track model metrics and deploy ML models with MLflow and Azure Machine Learning](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-use-mlflow).
#
# ## Clean Up
#
# On the **File** menu, click **Close and Halt** to close this notebook. Then close all Jupyter tabs in your browser and **stop** your compute instance to minimize costs.
